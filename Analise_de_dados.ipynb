# %% [markdown]
# <a href="https://colab.research.google.com/github/kaiqueoliveira327-cyber/Analise-de-Dados-Pre-o-Carbono/blob/main/Analise_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Dicionario**
# Link dos dados: (https://www.kaggle.com/datasets/sergionefedov/global-climate-and-energy-transition-2000-2026)
#
# Coluna:
# **date**: data - Object
#
# **year**: ano do Diário  - min 2005 max 2026 -int
#
# **market**:	     Mercado Mundial lançado EU_ETS / Califórnia / RGGI /
#
# Reino Unido_ETS / China_ETS - Object
#
# **currency**:	   Moeda utilizada EUR / USD / GBP / CNY - Object
#
# **price**:	     Preço de fechamento por tCO2 - Float

# %%
import pandas as pd #pandas
import matplotlib.pyplot as plt #matplots
import seaborn as sns #seaborn
#df = dataframes
df = pd.read_csv('Global.csv' , sep = ',')
df.head()
# Out:
#          date  year  market currency  price
# 0  2005-04-22  2005  EU_ETS      EUR   7.17
# 1  2005-04-25  2005  EU_ETS      EUR   7.13
# 2  2005-04-26  2005  EU_ETS      EUR   7.44
# 3  2005-04-27  2005  EU_ETS      EUR   7.38
# 4  2005-04-28  2005  EU_ETS      EUR   7.38

# %%
#Mostra os 5 Primeiros Dados da Analise
df.head()
# Out:
#          date  year  market currency  price
# 0  2005-04-22  2005  EU_ETS      EUR   7.17
# 1  2005-04-25  2005  EU_ETS      EUR   7.13
# 2  2005-04-26  2005  EU_ETS      EUR   7.44
# 3  2005-04-27  2005  EU_ETS      EUR   7.38
# 4  2005-04-28  2005  EU_ETS      EUR   7.38

# %%
#Mostra quantidades de Linhas e colunas
df.shape
# Out:
# (15866, 5)

# %%
#Mostra o nome das Colunas
print(df.columns)
# Out:
# Index(['date', 'year', 'market', 'currency', 'price'], dtype='object')

# %%
#Mostra os dados estatisticos
df.describe()
# Out:
#                year        price
# count  15866.000000  15866.00000
# mean    2017.986701     27.14063
# std        5.588788     28.23845
# min     2005.000000      0.05000
# 25%     2014.000000      6.36000
# 50%     2019.000000     15.50500
# 75%     2023.000000     35.19000
# max     2026.000000    119.52000

# %%
#Mostra Dados das Colunas, especificando valores ou objeto.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15866 entries, 0 to 15865
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      15866 non-null  object
#  1   year      15866 non-null  int64
#  2   market    15866 non-null  object
#  3   currency  15866 non-null  object
#  4   price     15866 non-null  float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 619.9+ KB

# %%
#Mostra o menor ano e maior ano dos dados
import pandas as pd
df_original = pd.read_csv('Global.csv' , sep = ',')
print('Menor ano ', df_original['year'].min())
print('Maior ano ', df_original['year'].max())
# Out:
# Menor ano  2005
# Maior ano  2026

# %%
#Descrevendo os dados estatisticos da Data
(df['date'].describe())
# Out:
# count          15866
# unique          5485
# top       2021-07-16
# freq               5
# Name: date, dtype: object

# %%
#Descrevendo os dados estatisticos das Moedas
(df['currency'].describe())
# Out:
# count     15866
# unique        4
# top         USD
# freq       7839
# Name: currency, dtype: object

# %%
#Visualiza as duas colunas de data e moeda
df = df[['date', 'currency']]
df.head(10)
# Out:
#          date currency
# 0  2005-04-22      EUR
# 1  2005-04-25      EUR
# 2  2005-04-26      EUR
# 3  2005-04-27      EUR
# 4  2005-04-28      EUR
# 5  2005-04-29      EUR
# 6  2005-05-02      EUR
# 7  2005-05-03      EUR
# 8  2005-05-04      EUR
# 9  2005-05-05      EUR

# %%
#Mostra os dados ordenados
df.sort_values('currency', ascending=False).head(10)
# Out:
#             date currency
# 7933  2023-04-07      USD
# 6089  2016-03-14      USD
# 6083  2016-03-04      USD
# 6084  2016-03-07      USD
# 6085  2016-03-08      USD
# 6086  2016-03-09      USD
# 6087  2016-03-10      USD
# 6088  2016-03-11      USD
# 6090  2016-03-15      USD
# 6081  2016-03-02      USD

# %%
#Esse código cria um gráfico de linha que mostra a quantidade de registros em cada ano.
df['date'] = pd.to_datetime(df['date'])

year_counts = df['date'].dt.year.value_counts().sort_index()

plt.figure(figsize=(10,6))
plt.plot(
    year_counts.index,
    year_counts.values,
    marker='o'
)

plt.title('Registros por Ano')
plt.xlabel('Ano')
plt.ylabel('Quantidade de Registros')

plt.show()

# %%
#Esse código cria um gráfico de pizza mostrando a distribuição das moedas mais frequentes na coluna
import matplotlib.pyplot as plt

moedas = df['currency'].value_counts().head(10)

plt.figure(figsize=(8,8))
plt.pie(moedas.values,
        labels=moedas.index,
        autopct='%1.1f%%')

plt.title('Distribuição das Moedas')
plt.show()
